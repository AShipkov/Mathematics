# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Практическое задание 3

# %% [markdown]
# ##  Тема “Предел функции”

# %% [markdown]
# ### Задание 1
# #### Предложить пример функции, не имеющей предела в нуле и в бесконечностях.

# %% [markdown]
# Решение:
# $$f(x) = sin(\frac{1}{x} + x)$$

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(rc={'figure.figsize': (18, 3)})

# %%
np.seterr(divide='ignore')

x = np.arange(-7, 7, 0.05)
y = np.sin(x + 1/x)

plt.axhline(linewidth=1.0, color="black")
plt.axvline(linewidth=1.0, color="black")

plt.plot(x,y)
plt.show()

# %%
np.seterr(divide='ignore')

x = np.arange(-0.1, 0.1, 0.00005)
y = np.sin(x + 1/x)

plt.axhline(linewidth=1.0, color="black")
plt.axvline(linewidth=1.0, color="black")

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Задание 2
# #### Привести пример функции, не имеющей предела в точке, но определенной в ней.

# %% [markdown]
# Решение:
# $$f(x) = sgn(x)$$

# %%
sns.set(rc={'figure.figsize': (18, 4)})
np.seterr(divide='ignore')

x = np.arange(-2, 2, 0.005)
y = np.sign(x)

plt.axhline(linewidth=1.0, color="red")
plt.axvline(linewidth=1.0, color="red")

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Задание 3
# ### Исследовать функцию $f(x)=x^3 - x^2$ по плану:
# ##### Область задания и область значений.
# ##### Нули функции и их кратность.
# ##### Отрезки знакопостоянства.
# ##### Интервалы монотонности.
# ##### Четность функции.
# ##### Ограниченность.
# ##### Периодичность.

# %%
sns.set(rc={'figure.figsize': (5, 3)})
np.seterr(divide='ignore')

x = np.arange(-0.8, 1.5, 0.01)
y = x**3 - x**2

plt.axhline(linewidth=2.0, color="black")
plt.axvline(linewidth=2.0, color="black")
plt.axis('equal')

plt.plot(x,y)
plt.show()

# %% [markdown]
# Решение:
#
# Область задания и область значений: $(-\infty; \infty)$ ;
#
# Нули функции: $f(x)=x^3 - x^2\implies f(x)=x^2(x - 1)\implies x_1 = 1, x_2 = 0$ ;
#
# Кратность нулей функции: $f'(x)= 3x^2 - 2x\implies f'(0)=0, f'(1)=1$. Нули функции $x_1 и x_2$ кратны ;
#
# Отрезки знакопостоянства: $(-\infty; 0), (0; 1);  (1; \infty)$ ;
#
# Четность функции: функция общего вида ;
#
# Ограниченность: функция не ограничена ;
#
# Периодичность: функция не периодична ;

# %% [markdown]
# ### Задание 4
# #### Найти предел $\lim_{x\to0}\frac{3x^3-2x^2}{4x^2}\implies \lim_{x\to0}\frac{3x-2}{4} = -\frac{1}{2}$

# %% [markdown]
# Решается домножением на сопряженный множитель - тут решено неверно $\lim_{x\to0}\frac{\sqrt{1 + x} - 1}{\sqrt[3]{1 + x} - 1}\implies \lim_{x\to0}\frac{\sqrt[3]{1 + x}(\sqrt[6]{1 + x} - \sqrt[3]{1 + x})}{\sqrt[3]{1 + x} - 1}\implies
# \begin{cases}
# x_1 = \sqrt[3]{1 + x} \\
# \lim_{x_1\to1}\frac{x_1(\sqrt{x_1} - x_1)}{x_1 - 1}
# \end{cases}\implies
# \begin{cases}
# x_1 = \sqrt[3]{1 + x} \\
# \lim_{x1\to1}\frac{1 - \frac{1}{\sqrt{x1}}}{\frac{1}{\sqrt{x1}}(1 - \frac{1}{\sqrt{x1}})}
# \end{cases}\implies
# \begin{cases}
# x_1 = \sqrt[3]{1 + x} \\
# \lim_{x_1\to1}\sqrt{x_1} = 1
# \end{cases}
# $
# $\lim_{x\to\infty}(\frac{x + 3}{x})^{4x+1}\implies \lim_{x\to\infty}(\frac{1}{1 + \frac{3}{x}})^{-4x-1}\implies \lim_{x\to\infty}((\frac{1}{1 + \frac{3}{x}})^{\frac{3}{x}})^{-\frac{4x^2}{3}-\frac{x}{3}}\implies e^{-\frac{1}{3}\lim_{x\to\infty}4x^2 + x}\implies e^{-\infty}$

# %% [markdown]
# ## Тема "Теоремы о пределах"

# %% [markdown]
# ## Задание 1
# ### Найти предел
# #### a. $\lim_{x\to\infty}\frac{sin2x}{4x}\implies \lim_{x\to\infty}\frac{2sinxcosx}{4x}\implies \lim_{x\to0}\frac{1}{2}\frac{sinx}{x}cosx = \frac{1}{2}$
# #### b.* $$\lim\limits_{x \to 0}\frac{\sqrt{1+x} -1}{\sqrt[3]{1+x}-1} = \left({\color{red}{\frac{0}{0}}}\right) =$$
# $$\lim\limits_{x \to 0}\frac{\sqrt{1+x} -1}{\sqrt[3]{1+x}-1} \bullet \frac{\sqrt{1+x} + 1}{\sqrt{1+x} + 1} \bullet \frac{\sqrt[3]{(1+x)^2} + \sqrt[3]{1+x} + 1}{\sqrt[3]{(1+x)^2} + \sqrt[3]{1+x} + 1} = $$$$\lim\limits_{x \to 0} \frac{1 + x - 1}{1 + x -1} \bullet \frac{\sqrt[3]{(1+x)^2} + \sqrt[3]{1+x} + 1}{\sqrt{1+x} + 1} = $$$$\lim\limits_{x \to 0}\frac{\sqrt[3]{(1+x)^2} + \sqrt[3]{1+x} + 1}{\sqrt{1+x} + 1} = \frac{1 + 1 + 1}{2} = \frac{3}{2} = 1\frac{1}{2}$$
# #### c.* $$\lim\limits_{x \to \infty}\left(\frac{x+3}{x}\right)^{4x+1} = ({\color{red}{\frac{\infty}{\infty}}}) = \lim\limits_{x \to \infty}\left(1 + \frac{3}{x}\right)^{4x+1} = ({\color{red}{1^\infty}}) = $$$$\lim\limits_{x \to \infty}\left(1 + \frac{3}{x}\right)^{\frac{x}{3} \bullet \frac{3}{x} \bullet (4x+1) } = $$$$ e^{\lim\limits_{x \to \infty}\frac{12x+1}{x}} = e^{12}$$
# #### d. $\lim_{x\to\infty}(\frac{4x+3}{4x-3})^{6x}\implies \lim_{x\to\infty}(1 + \frac{6}{4x-3})^{6x}\implies \lim_{x\to\infty}(1 + \frac{1}{\frac{4x-3}{6}})^{6x}\implies$

# %% [markdown]
# $\begin{cases}
#     x_1 = \frac{4x-3}{6} \implies x = \frac{6x + 3}{4} \\
#     \lim_{x\to\infty}(1 + \frac{1}{x_1})^{\frac{36x + 18}{4}}
# \end{cases}\implies
# \begin{cases}
#     x_1 = \frac{6x + 3}{4} \\
#     \lim_{x\to\infty}(1 + \frac{1}{x_1})^{9(x_1 + 2)}
# \end{cases}\implies
# \begin{cases}
#     x_1 = \frac{6x + 3}{4} \\
#     \lim_{x\to\infty}((1 + \frac{1}{x_1})^{x_1})^{\frac{9(x_1 + 2)}{x_1}}
# \end{cases}\implies
# \begin{cases}
#     x_1 = \frac{6x + 3}{4} \\
#     e^{9\lim_{x\to\infty}{1 + \frac{2}{x_1}}}
# \end{cases}\implies
# e^{9\lim_{x\to\infty}{1 + \frac{8}{6x + 3}}}\implies
# e^9
# $
